# %%
import os
from bs4 import BeautifulSoup
import sys
import json
import re
import time
import csv
import datetime

from getStringWithOnlyUtf8Symbols import getStringWithOnlyUtf8Symbols
from removeDuplicatesFromList import removeDuplicatesFromList

from makeDirectoryIfNotExist import makeDirectoryIfNotExist

from supervisedRequests.supervisedRequests import SupervisedRequests

# %%
supervisedRequests = SupervisedRequests()

# %%
def get_tweet_text(tweet):
    tweet_text_box = tweet.find("p", {"class": "TweetTextSize TweetTextSize--normal js-tweet-text tweet-text", "lang" : "en"})
    if tweet_text_box is None:
        tweet_text_box = tweet.find("p", {"lang" : "en"})
    if tweet_text_box is None:
        return None
    images_in_tweet_tag = tweet_text_box.find_all("a", {"class": "twitter-timeline-link u-hidden"})
    tweet_text = tweet_text_box.text
    for image_in_tweet_tag in images_in_tweet_tag:
        tweet_text = tweet_text.replace(image_in_tweet_tag.text, '')

    return tweet_text

def getTimestamp(content):
    #headerBox = content.find("div", {"class" : "stream-item-header"})
    #timeBox = headerBox.find("small", {"class" : "time"})
    timestamp = content.find("span" , {"data-time" : re.compile(r".*")})["data-time"]
    return timestamp

def getUserId(content):
    userData = content.find("a", {"class" : "account-group js-account-group js-action-profile js-user-profile-link js-nav"})
    return userData["data-user-id"]

def getUserName(content):
    userData = content.find("a", {"class" : "account-group js-account-group js-action-profile js-user-profile-link js-nav"})
    return userData["href"][1:]

def getTweetData(tweetData):
    tweetData = tweetData.find("li", {"data-item-id" : re.compile(r".*"), "data-item-type" : "tweet"})
    statusId = tweetData["data-item-id"]
    content = tweetData.find("div", {"class" : "content"})
    if content is None:
        print("Could not find content class")
        return None
    text = get_tweet_text(content)
    timestamp = getTimestamp(content)
    userId = getUserId(content)
    userName = getUserName(content)
    res = {"statusId" : statusId, "timestamp" : timestamp, "userId" : userId, "userName" : userName, "text" : text}
    return res
    
    
def get_this_page_tweets(soup):
    tweets_list = list()
    tweets = soup.find_all("li", {"data-item-type": "tweet"})
    for tweet in tweets:
        tweet_data = None
        try:
            tweet_data = get_tweet_text(tweet)
        except Exception as e:
            continue
            #ignore if there is any loading or tweet error

        if tweet_data:
            tweets_list.append(tweet_data)
            print(".", end="")
            sys.stdout.flush()

    return tweets_list

def get_this_page_replies(soup):
    replies = []
    elements = soup.findAll(None, {"class" : "js-tweet-text-container"})
    for el in elements:
        text = get_tweet_text(el)
        if text is not None:
            replies.append(getStringWithOnlyUtf8Symbols(text))
    return replies

def get_this_page_replies_data(soup):
    classType = "ThreadedConversation-tweet"
    replies = []
    elements = soup.findAll(None, {"class" : classType})
    for el in elements:
        data = getTweetData(el)
        if data is not None:
            replies.append(data)
    return replies

def getStatusIdsAndScreenName(soup):
    elementsWithDataConversationId = soup.findAll("div", {"data-conversation-id" : re.compile(r".*"), "data-screen-name" : re.compile(r".*")})
    result = []
    for el in elementsWithDataConversationId:
        if el not in result:
            result.append({"status" : el["data-conversation-id"], "name" : el["data-screen-name"]})
    return result
    
def get_statuses_ids(soup):
    elementsWithDataConversationId = soup.findAll("div", {"data-conversation-id" : re.compile(r".*")})
    result = []
    for el in elementsWithDataConversationId:
        if el not in result:
            result.append(el["data-conversation-id"])
        
    return result

def scrap_replies_of_status(username, statusId):
    replies = []
    url = "https://twitter.com/" + username + "/status/" + statusId
    response = supervisedRequests.get(url)
    if response is None:
        return replies
    
    html = response.text
    soup = BeautifulSoup(html, 'lxml')
    
    next_pointer = None
    try:
        divOfStreamContainerForComments = soup.find("div", {"class" : "ThreadedDescendants", "id" : "descendants"})
        next_pointer = divOfStreamContainerForComments.find("div", {"class": "stream-container"})["data-min-position"]
    except Exception as e:
        print(e)
        return replies
    
    while True:
        replies.extend(get_this_page_replies_data(soup))
        
        next_url = "https://twitter.com/i/" + username + \
                   "/conversation/" + statusId + \
                   "?include_available_features=1&" \
                   "include_entities=1&max_position=" + next_pointer + "&reset_error_state=false"
                    
        next_response = supervisedRequests.get(next_url)
        if next_response is None:
            print("url: " + url)
            print("next url: " + next_url)
            return replies
        
        replies_data = next_response.text
        replies_obj = None
        try:
            replies_obj = json.loads(replies_data)
        except:
            break
        
        if not replies_obj["has_more_items"] and not replies_obj["min_position"]:
            # using two checks here bcz in one case has_more_items was false but there were more items
            break
            
        next_pointer = replies_obj["min_position"]
        html = replies_obj["items_html"]
        soup = BeautifulSoup(html, 'lxml')
    
    return replies
    

def get_replies_data(username, pagesAmount=None):
    replies = []
    
    url = "http://www.twitter.com/" + username
    print("\n\nDownloading tweets for " + username)
    response = supervisedRequests.get(url)
    if response is None:
        return replies

    soup = BeautifulSoup(response.text, 'lxml')
 
    next_pointer = None
    try:
        next_pointer = soup.find("div", {"class": "stream-container"})["data-min-position"]
    except Exception as e:
        print(e)
        return replies
 
    i = 0
    while True:
        #statusIds = get_statuses_ids(soup)
        statusAndName = getStatusIdsAndScreenName(soup)
        for sn in statusAndName:
            #replies.extend(scrap_replies_of_status(username, id_))
            replies.extend(scrap_replies_of_status(sn["name"], sn["status"]))
        
        next_url = "https://twitter.com/i/profiles/show/" + username + \
                   "/timeline/tweets?include_available_features=1&" \
                   "include_entities=1&max_position=" + next_pointer + "&reset_error_state=false"

        next_response = supervisedRequests.get(next_url)
        if next_response is None:
            return replies
 
        tweets_data = next_response.text
        tweets_obj = None
        try:
            tweets_obj = json.loads(tweets_data)
        except:
            break
            
        if not tweets_obj["has_more_items"] and not tweets_obj["min_position"]:
            # using two checks here bcz in one case has_more_items was false but there were more items
            print("\nNo more tweets returned")
            break
        next_pointer = tweets_obj["min_position"]
        html = tweets_obj["items_html"]
        soup = BeautifulSoup(html, 'lxml')
        
        print("Next Page")
        i += 1
        
        if pagesAmount is not None and i >= pagesAmount:
            return replies
 
    return replies

# %%
account_list = None
with open("stockTwitters", "r") as fp:
    account_list = fp.read().split("\n")[:-1]

# %%
csvFile = "twitterCommentsWithServiceInfo.csv"
directory = "twitterCommentsWithServiceInfo"
makeDirectoryIfNotExist(directory)
writer = csv.writer(fp)
idx = 0
for stock in account_list:
    commentData = get_replies_data(stock)
    with open(os.path.join(directory, stock + ".json"), "w") as fp:
        json.dump(commentData, fp)
    with open(csvFile, "a") as fp:
        writer = csv.writer(fp)
        for cd in commentData:
            if cd["text"] == None:
                continue
            dateTime = datetime.datetime.fromtimestamp(int(cd["timestamp"])).strftime("%d-%m-%Y %H:%M:%S")
            link = "https://twitter.com/" + stock + "/status/" + str(cd["statusId"])
            record = [idx, dateTime, cd["timestamp"], cd["userId"], cd["userName"], cd["text"], link, stock]
            writer.writerow(record)
            idx += 1
    del commentData
# Out:
# Downloading tweets for OKEx_
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for HuobiGlobal
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/ichbinrobotech/status/997846210982567936
# next url: https://twitter.com/i/ichbinrobotech/conversation/997846210982567936?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAAAUN2R_OHhUAAw3Ze6w61TAADdkkWeVXkAAN2RK7JxbQAQ3ZRdnjl-AACAADAAAAAQIABAAAAA&reset_error_state=false
# response.status_code == 404
# url: https://twitter.com/ichbinrobotech/status/996984696398495744
# next url: https://twitter.com/i/ichbinrobotech/conversation/996984696398495744?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/HerbertRSim/status/992894802122366976
# next url: https://twitter.com/i/HerbertRSim/conversation/992894802122366976?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAAAgNyJwD01bgAQ3IoTiMl9AGDciWZ6_WAAINyH5Y-xbgAA3J0zpaVrABDchWSW6XUAENzIPJf9XQAQ3J3UKYFdABCAADAAAAAQIABAAAAA&reset_error_state=false
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/HerbertRSim/status/990997697346920448
# next url: https://twitter.com/i/HerbertRSim/conversation/990997697346920448?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAAA8NwLzpZZXQAA3CuJStlNABDcDDuoXU0AwNwTxvcVXgBQ3BFVBo1PAADcFyUbNVMAANwRNXptdQAA3AzdTzV5AADcD-ijtWkAENwM8SCteQAA3CSHT3lgAFDcEfCW2VMAENwQotRxbQAA3BAWbOV5ADDcJD-keU8AAIAAMAAAABAgAEAAAA&reset_error_state=false
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for ZbTalk
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for hitbtc
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for bitfinex
# Next Page
# response.status_code == 404
# url: https://twitter.com/paoloardoino/status/1023514159307268096
# next url: https://twitter.com/i/paoloardoino/conversation/1023514159307268096?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAAAwONIDxCxegAA40aWfAF7AADjTYVXNX0AMONFv-K5fQAA5AeVjIV6ACDj6nIkyWwAAOOX1p9tawBQ414iaPF3AADjWe4GDWwAAONTUP_lTQAA40qeLRlbABDjSgyxZX4AAIAAMAAAABAgAEAAAA&reset_error_state=false
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/paoloardoino/status/996092888693043200
# next url: https://twitter.com/i/paoloardoino/conversation/996092888693043200?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAAAoN0tcZihTAAQ3S2OtVlgAADdLqW2KWkAEN0tXAWJfQAA3UyM4RFrAADdet1GMXcAUN0tW35BdwAQ3UxcF71UAADdPWs-QWkAEN00Ru8hUAAAgAAwAAAAECAAQAAAA&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# 'NoneType' object has no attribute 'find'
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/BenIsgur/status/676069366832738304
# next url: https://twitter.com/i/BenIsgur/conversation/676069366832738304?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/bitfinex/status/445321434244448256
# next url: https://twitter.com/i/bitfinex/conversation/445321434244448256?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# response.status_code == 404
# url: https://twitter.com/bitfinex/status/432942671800184832
# next url: https://twitter.com/i/bitfinex/conversation/432942671800184832?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for BithumbOfficial
# Next Page
# response.status_code == 404
# Next Page
# response.status_code == 404
# response.status_code == 404
# response.status_code == 404
# Next Page
# Next Page
# response.status_code == 503
# url: https://twitter.com/BithumbOfficial/status/984612689354747904
# next url: https://twitter.com/i/BithumbOfficial/conversation/984612689354747904?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAABINqim6jNaQAg2tazeHF-ABDaolY0hXUAQNsIyQINaQAQ2qDC-J19AGDa-HRreUQAANqjBo0dXgAA2qDYGQ11ABDaoMMZXVMAENqgww25fgAA2zdKDI1EAADbCEMZ3W0AENsHm52dTwAA2wdYvoFgAADbBm7XUXUAANsFi0nZaQAA2wSg5Y11ABDbA7Lj8VAAAIAAMAAAABAgAEAAAA&reset_error_state=false
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for BitZExchange
# Next Page
# response.status_code == 404
# url: https://twitter.com/Manshodayo/status/1034378456010645504
# next url: https://twitter.com/i/Manshodayo/conversation/1034378456010645504?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAABAOW1-aotegAQ5cHnQfFHAADmJ_RDEWsAEOYpKbsteAAA5iiIRfF7ABDmJ_WPOX4AMOYn6CnJfgAA5daAGeFtACDlwQFsLW4AAOW9yZZ9RgAQ5a6uk3lOABDmRrhtWX0AAOY9XiuxXgAA5isDyrlbABDmKfJ5KX0AEOYn9Fm1bgAAgAAwAAAAECAAQAAAA&reset_error_state=false
# response.status_code == 404
# url: https://twitter.com/BagusCkb/status/1034378456010645504
# next url: https://twitter.com/i/BagusCkb/conversation/1034378456010645504?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAABAOW1-aotegAQ5cHnQfFHAADmJ_RDEWsAEOYpKbsteAAA5iiIRfF7ABDmJ_WPOX4AMOYn6CnJfgAA5daAGeFtACDlwQFsLW4AAOW9yZZ9RgAQ5a6uk3lOABDmRrhtWX0AAOY9XiuxXgAA5isDyrlbABDmKfJ5KX0AEOYn9Fm1bgAAgAAwAAAAECAAQAAAA&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/crypto_ziko/status/1016633625700233217
# next url: https://twitter.com/i/crypto_ziko/conversation/1016633625700233217?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/slutfultweets/status/1011141318175744001
# next url: https://twitter.com/i/slutfultweets/conversation/1011141318175744001?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for Bibox365
# Next Page
# response.status_code == 404
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for LBank_Exchange
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for BCEXofficial
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/khaganfi8ky/status/998391915249725441
# next url: https://twitter.com/i/khaganfi8ky/conversation/998391915249725441?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# response.status_code == 404
# url: https://twitter.com/SwftCoinn/status/997294760262975488
# next url: https://twitter.com/i/SwftCoinn/conversation/997294760262975488?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for digifinex
# Next Page
# response.status_code == 404
# response.status_code == 503
# url: https://twitter.com/digifinex/status/1014427028752293888
# next url: https://twitter.com/i/digifinex/conversation/1014427028752293888?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAAB0OFDGOaJXgBQ4UBD4UlTABDhP9vAjWkAAOMTcCfxbQAA4kYoGjlQAADicL1MAVAAAOFAJRcNTAAA4UAQ-ZV-ABDhQAH52UEAAOE_7iWldQAA4T_kXllTAADhQI2jIUwAAOF18Q3dTwAQ4UPGb_FPABDjFP5udXgAAOLUC3jpRgAA4nCnqA1TAADhzZfxzV4AEOGygKaRTQAA4bD9Z9lBAADhiey3lU8AAOGJ5-hZfgAA4YQoiXFQAADhgIkWKVAAAOF-vBzhawAA4X633zV1ACDhfY31GXcAAOF7jOOZaQAQ4Xi9nx1tACCAADAAAAAQIABAAAAA&reset_error_state=false
# response.status_code == 404
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for bitinka
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for ooobtcExchange
# Next Page
# response.status_code == 404
# Next Page
# response.status_code == 404
# url: https://twitter.com/Brendonb8282/status/985856640279703552
# next url: https://twitter.com/i/Brendonb8282/conversation/985856640279703552?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for Rightbtc_
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for CoinbasePro
# Next Page
# Next Page
# Next Page
# Next Page
# HTTPSConnectionPool(host='twitter.com', port=443): Max retries exceeded with url: /i/CoinbasePro/conversation/943307603760648193?include_available_features=1&include_entities=1&max_position=DAACDwABCgAAABANF01RbxfQBw0XT2ZA1uADDRdQqawX4AANF02mg1XAAA0XToppVtAADRdTz11WsAANF1HXf9fQAQ0XTkdvVgAEDRdPTwzVwAANF1FkoVeQAA0XTZCw11ACDRdReCWWAAANF1QhQVdQAQ0XUcv_F1AADRdPlxXW0AANF1A3KVRAAAgAAwAAAAECAAQAAAA&reset_error_state=false (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f7be9a1a978>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Blocking requests for 10 seconds.
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for Cryptonex_CNX
# Next Page
# Next Page
#
# No more tweets returned
#
#
# Downloading tweets for AllCoinEx
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# Next Page
# HTTPSConnectionPool(host='twitter.com', port=443): Max retries exceeded with url: /AllCoinEx/status/923116735896711170 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f7beb381da0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# Blocking requests for 10 seconds.
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/CryptoCc/status/498628919084331011
# next url: https://twitter.com/i/CryptoCc/conversation/498628919084331011?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
# Next Page
# Next Page
# Next Page
# Next Page
# Next Page
# response.status_code == 404
# url: https://twitter.com/devnullius/status/470427237804544000
# next url: https://twitter.com/i/devnullius/conversation/470427237804544000?include_available_features=1&include_entities=1&max_position=&reset_error_state=false
